# %%
# !source venv/bin/activate

# %%
import pandas as pd

# %%
df = pd.read_csv('/home/amadgakkhar/code/MLOps-Project/dataset.csv')
print(df.head())
print(df.shape)
print(df.columns)
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# (5110, 12)
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %% [markdown]
# Need to convert csv data to dict format. Functional Technique of MongoDB. MYSQl is a Structured Database. While MD can also store unstructured Data.

# %%
data = df.to_dict(orient="records")
# data

# %%
len(data)
# Out:
# 5110

# %%
data[0]['age']
# Out:
# 67.0

# %%
import urllib
DB_NAME = 'heart_disease'
COLLECTION_NAME = "stroke_data"
CONNECTION_URL = "mongodb+srv://amdgakkhar:Kv2oEdQmIVqgS8pX@cluster0.uhwbkat.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
import pymongo as pm
import certifi

ca = certifi.where()
client = pm.MongoClient(CONNECTION_URL,tlsCAFile=ca)
database = client[DB_NAME]
collection = database[COLLECTION_NAME]
# record = collection.insert_many(data)


records = collection.find()
# records

for i, j in enumerate(records):
    print(f"Record Number, {i}: {j}")
    
# df = pd.DataFrame(list(collection.find()))
# df.head()
# # print(df.columns)
# Out:
# Record Number, 0: {'_id': ObjectId('66a72d6248181a51a2035da0'), 'id': 60182, 'gender': 'Female', 'age': 49.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 171.23, 'bmi': 34.4, 'smoking_status': 'smokes', 'stroke': 1}
# Record Number, 1: {'_id': ObjectId('66a72d6248181a51a2035daf'), 'id': 27458, 'gender': 'Female', 'age': 60.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 89.22, 'bmi': 37.8, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 2: {'_id': ObjectId('66a72d6248181a51a2035d9f'), 'id': 31112, 'gender': 'Male', 'age': 80.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 105.92, 'bmi': 32.5, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 3: {'_id': ObjectId('66a72d6248181a51a2035da3'), 'id': 53882, 'gender': 'Male', 'age': 74.0, 'hypertension': 1, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 70.09, 'bmi': 27.4, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 4: {'_id': ObjectId('66a72d6248181a51a2035db6'), 'id': 70822, 'gender': 'Male', 'age': 80.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Rural', 'avg_glucose_level': 104.12, 'bmi': 23.5, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 5: {'_id': ObjectId('66a72d6248181a51a2035dad'), 'id': 56112, 'gender': 'Male', 'age': 64.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 191.61, 'bmi': 37.5, 'smoking_status': 'smokes', 'stroke': 1}
# Record Number, 6: {'_id': ObjectId('66a72d6248181a51a2035da1'), 'id': 1665, 'gender': 'Female', 'age': 79.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Rural', 'avg_glucose_level': 174.12, 'bmi': 24.0, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 7: {'_id': ObjectId('66a72d6248181a51a2035db3'), 'id': 68794, 'gender': 'Female', 'age': 79.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 228.7, 'bmi': 26.6, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 8: {'_id': ObjectId('66a72d6248181a51a2035dbb'), 'id': 43717, 'gender': 'Male', 'age': 57.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 212.08, 'bmi': 44.2, 'smoking_status': 'smokes', 'stroke': 1}
# Record Number, 9: {'_id': ObjectId('66a72d6248181a51a2035dc6'), 'id': 1261, 'gender': 'Male', 'age': 54.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 71.22, 'bmi': 28.5, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 10: {'_id': ObjectId('66a72d6248181a51a2035ddc'), 'id': 19557, 'gender': 'Female', 'age': 45.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 93.72, 'bmi': 30.2, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 11: {'_id': ObjectId('66a72d6248181a51a2035dd1'), 'id': 59190, 'gender': 'Female', 'age': 79.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 127.29, 'bmi': 27.7, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 12: {'_id': ObjectId('66a72d6248181a51a2035dd6'), 'id': 66400, 'gender': 'Male', 'age': 78.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 237.75, 'bmi': nan, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 13: {'_id': ObjectId('66a72d6248181a51a2035dd3'), 'id': 8752, 'gender': 'Female', 'age': 63.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Govt_job', 'Residence_type': 'Urban', 'avg_glucose_level': 197.54, 'bmi': nan, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 14: {'_id': ObjectId('66a72d6248181a51a2035db8'), 'id': 61843, 'gender': 'Male', 'age': 58.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 189.84, 'bmi': nan, 'smoking_status': 'Unknown', 'stroke': 1}
# Record Number, 15: {'_id': ObjectId('66a72d6248181a51a2035dbf'), 'id': 14248, 'gender': 'Male', 'age': 48.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Govt_job', 'Residence_type': 'Urban', 'avg_glucose_level': 84.2, 'bmi': 29.7, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 16: {'_id': ObjectId('66a72d6248181a51a2035dc0'), 'id': 712, 'gender': 'Female', 'age': 82.0, 'hypertension': 1, 'heart_disease': 1, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 84.03, 'bmi': 26.5, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 17: {'_id': ObjectId('66a72d6248181a51a2035dcc'), 'id': 47472, 'gender': 'Female', 'age': 58.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 107.26, 'bmi': 38.6, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 18: {'_id': ObjectId('66a72d6248181a51a2035ddb'), 'id': 65842, 'gender': 'Female', 'age': 67.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Rural', 'avg_glucose_level': 61.94, 'bmi': 25.3, 'smoking_status': 'smokes', 'stroke': 1}
# Record Number, 19: {'_id': ObjectId('66a72d6248181a51a2035da6'), 'id': 60491, 'gender': 'Female', 'age': 78.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 58.57, 'bmi': 24.2, 'smoking_status': 'Unknown', 'stroke': 1}
# Record Number, 20: {'_id': ObjectId('66a72d6248181a51a2035db4'), 'id': 64778, 'gender': 'Male', 'age': 82.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 208.3, 'bmi': 32.5, 'smoking_status': 'Unknown', 'stroke': 1}
# Record Number, 21: {'_id': ObjectId('66a72d6248181a51a2035db2'), 'id': 13861, 'gender': 'Female', 'age': 52.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 233.29, 'bmi': 48.9, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 22: {'_id': ObjectId('66a72d6248181a51a2035dc5'), 'id': 4651, 'gender': 'Male', 'age': 78.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 78.03, 'bmi': 23.9, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 23: {'_id': ObjectId('66a72d6248181a51a2035dca'), 'id': 19824, 'gender': 'Male', 'age': 76.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 243.58, 'bmi': 33.6, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 24: {'_id': ObjectId('66a72d6248181a51a2035dd8'), 'id': 5111, 'gender': 'Female', 'age': 54.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Govt_job', 'Residence_type': 'Urban', 'avg_glucose_level': 180.93, 'bmi': 27.7, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 25: {'_id': ObjectId('66a72d6248181a51a2035d9d'), 'id': 9046, 'gender': 'Male', 'age': 67.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 228.69, 'bmi': 36.6, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 26: {'_id': ObjectId('66a72d6248181a51a2035da9'), 'id': 12175, 'gender': 'Female', 'age': 54.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 104.51, 'bmi': 27.3, 'smoking_status': 'smokes', 'stroke': 1}
# Record Number, 27: {'_id': ObjectId('66a72d6248181a51a2035d9e'), 'id': 51676, 'gender': 'Female', 'age': 61.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Rural', 'avg_glucose_level': 202.21, 'bmi': nan, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 28: {'_id': ObjectId('66a72d6248181a51a2035dc7'), 'id': 61960, 'gender': 'Male', 'age': 82.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 144.9, 'bmi': 26.4, 'smoking_status': 'smokes', 'stroke': 1}
# Record Number, 29: {'_id': ObjectId('66a72d6248181a51a2035db7'), 'id': 38047, 'gender': 'Female', 'age': 65.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 100.98, 'bmi': 28.2, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 30: {'_id': ObjectId('66a72d6248181a51a2035dcd'), 'id': 35626, 'gender': 'Male', 'age': 81.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 99.33, 'bmi': 33.7, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 31: {'_id': ObjectId('66a72d6248181a51a2035dac'), 'id': 58202, 'gender': 'Female', 'age': 50.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Rural', 'avg_glucose_level': 167.41, 'bmi': 30.9, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 32: {'_id': ObjectId('66a72d6248181a51a2035db9'), 'id': 54827, 'gender': 'Male', 'age': 69.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 195.23, 'bmi': 28.3, 'smoking_status': 'smokes', 'stroke': 1}
# Record Number, 33: {'_id': ObjectId('66a72d6248181a51a2035dbe'), 'id': 54401, 'gender': 'Male', 'age': 80.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 252.72, 'bmi': 30.5, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 34: {'_id': ObjectId('66a72d6248181a51a2035db1'), 'id': 70630, 'gender': 'Female', 'age': 71.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Govt_job', 'Residence_type': 'Rural', 'avg_glucose_level': 193.94, 'bmi': 22.4, 'smoking_status': 'smokes', 'stroke': 1}
# Record Number, 35: {'_id': ObjectId('66a72d6248181a51a2035dbc'), 'id': 33879, 'gender': 'Male', 'age': 42.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 83.41, 'bmi': 25.4, 'smoking_status': 'Unknown', 'stroke': 1}
# Record Number, 36: {'_id': ObjectId('66a72d6248181a51a2035dc4'), 'id': 62602, 'gender': 'Female', 'age': 49.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 60.91, 'bmi': 29.9, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 37: {'_id': ObjectId('66a72d6248181a51a2035dcb'), 'id': 37937, 'gender': 'Female', 'age': 75.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'No', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 109.78, 'bmi': nan, 'smoking_status': 'Unknown', 'stroke': 1}
# Record Number, 38: {'_id': ObjectId('66a72d6248181a51a2035da2'), 'id': 56669, 'gender': 'Male', 'age': 81.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 186.21, 'bmi': 29.0, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 39: {'_id': ObjectId('66a72d6248181a51a2035dae'), 'id': 34120, 'gender': 'Male', 'age': 75.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 221.29, 'bmi': 25.8, 'smoking_status': 'smokes', 'stroke': 1}
# Record Number, 40: {'_id': ObjectId('66a72d6248181a51a2035db0'), 'id': 25226, 'gender': 'Male', 'age': 57.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'No', 'work_type': 'Govt_job', 'Residence_type': 'Urban', 'avg_glucose_level': 217.08, 'bmi': nan, 'smoking_status': 'Unknown', 'stroke': 1}
# Record Number, 41: {'_id': ObjectId('66a72d6248181a51a2035dba'), 'id': 69160, 'gender': 'Male', 'age': 59.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 211.78, 'bmi': nan, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 42: {'_id': ObjectId('66a72d6248181a51a2035dbd'), 'id': 39373, 'gender': 'Female', 'age': 82.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 196.92, 'bmi': 22.2, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 43: {'_id': ObjectId('66a72d6248181a51a2035dc3'), 'id': 47306, 'gender': 'Male', 'age': 58.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 92.62, 'bmi': 32.0, 'smoking_status': 'Unknown', 'stroke': 1}
# Record Number, 44: {'_id': ObjectId('66a72d6248181a51a2035dc9'), 'id': 7937, 'gender': 'Male', 'age': 60.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Govt_job', 'Residence_type': 'Urban', 'avg_glucose_level': 213.03, 'bmi': 20.2, 'smoking_status': 'smokes', 'stroke': 1}
# Record Number, 45: {'_id': ObjectId('66a72d6248181a51a2035dd0'), 'id': 15102, 'gender': 'Male', 'age': 78.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 75.32, 'bmi': nan, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 46: {'_id': ObjectId('66a72d6248181a51a2035dd7'), 'id': 58631, 'gender': 'Male', 'age': 73.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 194.99, 'bmi': 32.8, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 47: {'_id': ObjectId('66a72d6248181a51a2035dd9'), 'id': 10710, 'gender': 'Female', 'age': 56.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 185.17, 'bmi': 40.4, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 48: {'_id': ObjectId('66a72d6248181a51a2035dda'), 'id': 55927, 'gender': 'Female', 'age': 80.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 74.9, 'bmi': 22.2, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 49: {'_id': ObjectId('66a72d6248181a51a2035da5'), 'id': 27419, 'gender': 'Female', 'age': 59.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 76.15, 'bmi': nan, 'smoking_status': 'Unknown', 'stroke': 1}
# Record Number, 50: {'_id': ObjectId('66a72d6248181a51a2035da7'), 'id': 12109, 'gender': 'Female', 'age': 81.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 80.43, 'bmi': 29.7, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 51: {'_id': ObjectId('66a72d6248181a51a2035daa'), 'id': 8213, 'gender': 'Male', 'age': 78.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 219.84, 'bmi': nan, 'smoking_status': 'Unknown', 'stroke': 1}
# Record Number, 52: {'_id': ObjectId('66a72d6248181a51a2035dcf'), 'id': 18587, 'gender': 'Female', 'age': 76.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 89.96, 'bmi': nan, 'smoking_status': 'Unknown', 'stroke': 1}
# Record Number, 53: {'_id': ObjectId('66a72d6248181a51a2035da4'), 'id': 10434, 'gender': 'Female', 'age': 69.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 94.39, 'bmi': 22.8, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 54: {'_id': ObjectId('66a72d6248181a51a2035dab'), 'id': 5317, 'gender': 'Female', 'age': 79.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 214.09, 'bmi': 28.2, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 55: {'_id': ObjectId('66a72d6248181a51a2035dce'), 'id': 36338, 'gender': 'Female', 'age': 39.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 58.09, 'bmi': 39.2, 'smoking_status': 'smokes', 'stroke': 1}
# Record Number, 56: {'_id': ObjectId('66a72d6248181a51a2035dd2'), 'id': 47167, 'gender': 'Female', 'age': 77.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 124.13, 'bmi': 31.4, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 57: {'_id': ObjectId('66a72d6248181a51a2035dc8'), 'id': 1845, 'gender': 'Female', 'age': 63.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 90.9, 'bmi': nan, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 58: {'_id': ObjectId('66a72d6248181a51a2035da8'), 'id': 12095, 'gender': 'Female', 'age': 61.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Govt_job', 'Residence_type': 'Rural', 'avg_glucose_level': 120.46, 'bmi': 36.8, 'smoking_status': 'smokes', 'stroke': 1}
# Record Number, 59: {'_id': ObjectId('66a72d6248181a51a2035db5'), 'id': 4219, 'gender': 'Male', 'age': 71.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 102.87, 'bmi': 27.2, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 60: {'_id': ObjectId('66a72d6248181a51a2035dd5'), 'id': 38829, 'gender': 'Female', 'age': 82.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 59.32, 'bmi': 33.2, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 61: {'_id': ObjectId('66a72d6248181a51a2035dc1'), 'id': 47269, 'gender': 'Male', 'age': 74.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 219.72, 'bmi': 33.7, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 62: {'_id': ObjectId('66a72d6248181a51a2035dc2'), 'id': 24977, 'gender': 'Female', 'age': 72.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 74.63, 'bmi': 23.1, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 63: {'_id': ObjectId('66a72d6248181a51a2035dd4'), 'id': 25831, 'gender': 'Male', 'age': 63.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 196.71, 'bmi': 36.5, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 64: {'_id': ObjectId('66a72d6248181a51a2035dec'), 'id': 42117, 'gender': 'Male', 'age': 43.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 143.43, 'bmi': 45.9, 'smoking_status': 'Unknown', 'stroke': 1}
# Record Number, 65: {'_id': ObjectId('66a72d6248181a51a2035dde'), 'id': 17013, 'gender': 'Male', 'age': 78.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 113.01, 'bmi': 24.0, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 66: {'_id': ObjectId('66a72d6248181a51a2035de8'), 'id': 66159, 'gender': 'Female', 'age': 80.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Rural', 'avg_glucose_level': 66.72, 'bmi': 21.7, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 67: {'_id': ObjectId('66a72d6248181a51a2035dea'), 'id': 71673, 'gender': 'Female', 'age': 79.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 110.85, 'bmi': 24.1, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 68: {'_id': ObjectId('66a72d6248181a51a2035de2'), 'id': 7371, 'gender': 'Female', 'age': 80.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Rural', 'avg_glucose_level': 72.67, 'bmi': 28.9, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 69: {'_id': ObjectId('66a72d6248181a51a2035de7'), 'id': 19773, 'gender': 'Female', 'age': 52.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 96.59, 'bmi': 26.4, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 70: {'_id': ObjectId('66a72d6248181a51a2035df3'), 'id': 3253, 'gender': 'Male', 'age': 61.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 111.81, 'bmi': 27.3, 'smoking_status': 'smokes', 'stroke': 1}
# Record Number, 71: {'_id': ObjectId('66a72d6248181a51a2035dfd'), 'id': 35512, 'gender': 'Female', 'age': 70.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Rural', 'avg_glucose_level': 76.34, 'bmi': 24.4, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 72: {'_id': ObjectId('66a72d6248181a51a2035e01'), 'id': 12363, 'gender': 'Male', 'age': 64.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Govt_job', 'Residence_type': 'Urban', 'avg_glucose_level': 74.1, 'bmi': 28.8, 'smoking_status': 'Unknown', 'stroke': 1}
# Record Number, 73: {'_id': ObjectId('66a72d6248181a51a2035de4'), 'id': 2326, 'gender': 'Female', 'age': 67.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 179.12, 'bmi': 28.1, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 74: {'_id': ObjectId('66a72d6248181a51a2035df7'), 'id': 28291, 'gender': 'Female', 'age': 79.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 226.98, 'bmi': 29.8, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 75: {'_id': ObjectId('66a72d6248181a51a2035e00'), 'id': 4639, 'gender': 'Female', 'age': 69.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Govt_job', 'Residence_type': 'Urban', 'avg_glucose_level': 82.81, 'bmi': 28.0, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 76: {'_id': ObjectId('66a72d6248181a51a2035e06'), 'id': 2346, 'gender': 'Male', 'age': 58.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 82.3, 'bmi': nan, 'smoking_status': 'smokes', 'stroke': 1}
# Record Number, 77: {'_id': ObjectId('66a72d6248181a51a2035de1'), 'id': 6118, 'gender': 'Male', 'age': 59.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 86.23, 'bmi': 30.0, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 78: {'_id': ObjectId('66a72d6248181a51a2035de6'), 'id': 50784, 'gender': 'Male', 'age': 63.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 228.56, 'bmi': 27.4, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 79: {'_id': ObjectId('66a72d6248181a51a2035e10'), 'id': 53401, 'gender': 'Male', 'age': 71.0, 'hypertension': 1, 'heart_disease': 1, 'ever_married': 'No', 'work_type': 'Govt_job', 'Residence_type': 'Rural', 'avg_glucose_level': 216.94, 'bmi': 30.9, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 80: {'_id': ObjectId('66a72d6248181a51a2035e11'), 'id': 60744, 'gender': 'Male', 'age': 61.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Rural', 'avg_glucose_level': 76.11, 'bmi': 27.3, 'smoking_status': 'smokes', 'stroke': 1}
# Record Number, 81: {'_id': ObjectId('66a72d6248181a51a2035df9'), 'id': 66315, 'gender': 'Female', 'age': 57.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 68.02, 'bmi': 37.5, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 82: {'_id': ObjectId('66a72d6248181a51a2035e14'), 'id': 5563, 'gender': 'Female', 'age': 77.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 105.22, 'bmi': 31.0, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 83: {'_id': ObjectId('66a72d6248181a51a2035df5'), 'id': 14499, 'gender': 'Male', 'age': 47.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 86.94, 'bmi': 41.1, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 84: {'_id': ObjectId('66a72d6248181a51a2035dfc'), 'id': 2458, 'gender': 'Female', 'age': 78.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 235.63, 'bmi': 32.3, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 85: {'_id': ObjectId('66a72d6248181a51a2035e15'), 'id': 68798, 'gender': 'Female', 'age': 58.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 59.86, 'bmi': 28.0, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 86: {'_id': ObjectId('66a72d6248181a51a2035e19'), 'id': 14164, 'gender': 'Female', 'age': 72.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 219.91, 'bmi': nan, 'smoking_status': 'Unknown', 'stroke': 1}
# Record Number, 87: {'_id': ObjectId('66a72d6248181a51a2035de3'), 'id': 70676, 'gender': 'Female', 'age': 76.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Govt_job', 'Residence_type': 'Rural', 'avg_glucose_level': 62.57, 'bmi': nan, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 88: {'_id': ObjectId('66a72d6248181a51a2035ddd'), 'id': 7356, 'gender': 'Male', 'age': 75.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 104.72, 'bmi': nan, 'smoking_status': 'Unknown', 'stroke': 1}
# Record Number, 89: {'_id': ObjectId('66a72d6248181a51a2035de5'), 'id': 27169, 'gender': 'Female', 'age': 66.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Govt_job', 'Residence_type': 'Rural', 'avg_glucose_level': 116.55, 'bmi': 31.1, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 90: {'_id': ObjectId('66a72d6248181a51a2035ddf'), 'id': 17004, 'gender': 'Female', 'age': 70.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 221.58, 'bmi': 47.5, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 91: {'_id': ObjectId('66a72d6248181a51a2035df8'), 'id': 51169, 'gender': 'Male', 'age': 81.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 72.81, 'bmi': 26.3, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 92: {'_id': ObjectId('66a72d6248181a51a2035dfa'), 'id': 37726, 'gender': 'Female', 'age': 80.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 68.56, 'bmi': 26.2, 'smoking_status': 'Unknown', 'stroke': 1}
# Record Number, 93: {'_id': ObjectId('66a72d6248181a51a2035e08'), 'id': 12062, 'gender': 'Female', 'age': 54.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Rural', 'avg_glucose_level': 191.82, 'bmi': 40.4, 'smoking_status': 'smokes', 'stroke': 1}
# Record Number, 94: {'_id': ObjectId('66a72d6248181a51a2035e1a'), 'id': 50522, 'gender': 'Female', 'age': 72.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Govt_job', 'Residence_type': 'Urban', 'avg_glucose_level': 131.41, 'bmi': 28.4, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 95: {'_id': ObjectId('66a72d6248181a51a2035de9'), 'id': 36236, 'gender': 'Male', 'age': 80.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 240.09, 'bmi': 27.0, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 96: {'_id': ObjectId('66a72d6248181a51a2035de0'), 'id': 72366, 'gender': 'Male', 'age': 76.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 104.47, 'bmi': 20.3, 'smoking_status': 'Unknown', 'stroke': 1}
# Record Number, 97: {'_id': ObjectId('66a72d6248181a51a2035dff'), 'id': 8154, 'gender': 'Male', 'age': 57.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Govt_job', 'Residence_type': 'Urban', 'avg_glucose_level': 78.92, 'bmi': 27.7, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 98: {'_id': ObjectId('66a72d6248181a51a2035e02'), 'id': 63973, 'gender': 'Female', 'age': 77.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Govt_job', 'Residence_type': 'Rural', 'avg_glucose_level': 190.32, 'bmi': 31.4, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 99: {'_id': ObjectId('66a72d6248181a51a2035e09'), 'id': 30456, 'gender': 'Female', 'age': 79.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 93.05, 'bmi': 24.2, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 100: {'_id': ObjectId('66a72d6248181a51a2035e0c'), 'id': 48405, 'gender': 'Male', 'age': 80.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 68.53, 'bmi': 24.2, 'smoking_status': 'smokes', 'stroke': 1}
# Record Number, 101: {'_id': ObjectId('66a72d6248181a51a2035e17'), 'id': 13491, 'gender': 'Male', 'age': 80.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 259.63, 'bmi': 31.7, 'smoking_status': 'smokes', 'stroke': 1}
# Record Number, 102: {'_id': ObjectId('66a72d6248181a51a2035ded'), 'id': 57419, 'gender': 'Male', 'age': 59.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 96.16, 'bmi': 44.1, 'smoking_status': 'Unknown', 'stroke': 1}
# Record Number, 103: {'_id': ObjectId('66a72d6248181a51a2035df1'), 'id': 70042, 'gender': 'Male', 'age': 58.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 71.2, 'bmi': nan, 'smoking_status': 'Unknown', 'stroke': 1}
# Record Number, 104: {'_id': ObjectId('66a72d6248181a51a2035df2'), 'id': 32399, 'gender': 'Male', 'age': 54.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 96.97, 'bmi': 29.1, 'smoking_status': 'smokes', 'stroke': 1}
# Record Number, 105: {'_id': ObjectId('66a72d6248181a51a2035dfb'), 'id': 54385, 'gender': 'Male', 'age': 45.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 64.14, 'bmi': 29.4, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 106: {'_id': ObjectId('66a72d6248181a51a2035e03'), 'id': 45277, 'gender': 'Female', 'age': 74.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 231.61, 'bmi': 34.6, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 107: {'_id': ObjectId('66a72d6248181a51a2035e0d'), 'id': 36706, 'gender': 'Female', 'age': 76.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 106.41, 'bmi': nan, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 108: {'_id': ObjectId('66a72d6248181a51a2035e04'), 'id': 4712, 'gender': 'Female', 'age': 81.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Rural', 'avg_glucose_level': 78.7, 'bmi': 19.4, 'smoking_status': 'Unknown', 'stroke': 1}
# Record Number, 109: {'_id': ObjectId('66a72d6248181a51a2035deb'), 'id': 45805, 'gender': 'Female', 'age': 51.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 165.31, 'bmi': nan, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 110: {'_id': ObjectId('66a72d6248181a51a2035e05'), 'id': 33175, 'gender': 'Female', 'age': 57.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Govt_job', 'Residence_type': 'Urban', 'avg_glucose_level': 110.52, 'bmi': 28.5, 'smoking_status': 'Unknown', 'stroke': 1}
# Record Number, 111: {'_id': ObjectId('66a72d6248181a51a2035e0a'), 'id': 59125, 'gender': 'Female', 'age': 53.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Govt_job', 'Residence_type': 'Urban', 'avg_glucose_level': 64.17, 'bmi': 41.5, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 112: {'_id': ObjectId('66a72d6248181a51a2035e0e'), 'id': 41069, 'gender': 'Female', 'age': 45.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 224.1, 'bmi': 56.6, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 113: {'_id': ObjectId('66a72d6248181a51a2035e12'), 'id': 7547, 'gender': 'Male', 'age': 74.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 72.96, 'bmi': 31.3, 'smoking_status': 'smokes', 'stroke': 1}
# Record Number, 114: {'_id': ObjectId('66a72d6248181a51a2035e1b'), 'id': 3352, 'gender': 'Male', 'age': 78.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 93.13, 'bmi': nan, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 115: {'_id': ObjectId('66a72d6248181a51a2035e1c'), 'id': 70943, 'gender': 'Female', 'age': 80.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 73.54, 'bmi': 24.0, 'smoking_status': 'Unknown', 'stroke': 1}
# Record Number, 116: {'_id': ObjectId('66a72d6248181a51a2035dee'), 'id': 26015, 'gender': 'Female', 'age': 66.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 101.45, 'bmi': nan, 'smoking_status': 'Unknown', 'stroke': 1}
# Record Number, 117: {'_id': ObjectId('66a72d6248181a51a2035df6'), 'id': 49130, 'gender': 'Male', 'age': 74.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 98.55, 'bmi': 25.6, 'smoking_status': 'Unknown', 'stroke': 1}
# Record Number, 118: {'_id': ObjectId('66a72d6248181a51a2035e18'), 'id': 44033, 'gender': 'Male', 'age': 56.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 249.31, 'bmi': 35.8, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 119: {'_id': ObjectId('66a72d6248181a51a2035def'), 'id': 26727, 'gender': 'Female', 'age': 79.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 88.92, 'bmi': 22.9, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 120: {'_id': ObjectId('66a72d6248181a51a2035df0'), 'id': 66638, 'gender': 'Female', 'age': 68.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 79.79, 'bmi': 29.7, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 121: {'_id': ObjectId('66a72d6248181a51a2035df4'), 'id': 71796, 'gender': 'Female', 'age': 70.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 59.35, 'bmi': 32.3, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 122: {'_id': ObjectId('66a72d6248181a51a2035dfe'), 'id': 56841, 'gender': 'Male', 'age': 58.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 240.59, 'bmi': 31.4, 'smoking_status': 'smokes', 'stroke': 1}
# Record Number, 123: {'_id': ObjectId('66a72d6248181a51a2035e07'), 'id': 42072, 'gender': 'Female', 'age': 50.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 73.18, 'bmi': 30.3, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 124: {'_id': ObjectId('66a72d6248181a51a2035e0b'), 'id': 56546, 'gender': 'Male', 'age': 79.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 129.98, 'bmi': 22.6, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 125: {'_id': ObjectId('66a72d6248181a51a2035e16'), 'id': 72918, 'gender': 'Female', 'age': 53.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 62.55, 'bmi': 30.3, 'smoking_status': 'Unknown', 'stroke': 1}
# Record Number, 126: {'_id': ObjectId('66a72d6248181a51a2035e0f'), 'id': 71639, 'gender': 'Female', 'age': 68.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Govt_job', 'Residence_type': 'Urban', 'avg_glucose_level': 82.1, 'bmi': 27.1, 'smoking_status': 'Unknown', 'stroke': 1}
# Record Number, 127: {'_id': ObjectId('66a72d6248181a51a2035e13'), 'id': 31720, 'gender': 'Female', 'age': 38.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 82.28, 'bmi': 24.0, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 128: {'_id': ObjectId('66a72d6248181a51a2035e22'), 'id': 31563, 'gender': 'Female', 'age': 38.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 101.45, 'bmi': nan, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 129: {'_id': ObjectId('66a72d6248181a51a2035e20'), 'id': 16817, 'gender': 'Female', 'age': 78.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 130.54, 'bmi': 20.1, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 130: {'_id': ObjectId('66a72d6248181a51a2035e21'), 'id': 69551, 'gender': 'Male', 'age': 69.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 182.99, 'bmi': 36.5, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 131: {'_id': ObjectId('66a72d6248181a51a2035e2b'), 'id': 8045, 'gender': 'Female', 'age': 74.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 70.28, 'bmi': 21.8, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 132: {'_id': ObjectId('66a72d6248181a51a2035e32'), 'id': 58978, 'gender': 'Female', 'age': 70.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 239.07, 'bmi': 26.1, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 133: {'_id': ObjectId('66a72d6248181a51a2035e2c'), 'id': 37651, 'gender': 'Female', 'age': 69.0, 'hypertension': 1, 'heart_disease': 1, 'ever_married': 'No', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 72.17, 'bmi': 36.8, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 134: {'_id': ObjectId('66a72d6248181a51a2035e4a'), 'id': 2182, 'gender': 'Female', 'age': 80.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Rural', 'avg_glucose_level': 91.02, 'bmi': 32.9, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 135: {'_id': ObjectId('66a72d6248181a51a2035e34'), 'id': 46703, 'gender': 'Male', 'age': 68.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 223.83, 'bmi': 31.9, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 136: {'_id': ObjectId('66a72d6248181a51a2035e3e'), 'id': 16590, 'gender': 'Male', 'age': 71.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 81.76, 'bmi': nan, 'smoking_status': 'smokes', 'stroke': 1}
# Record Number, 137: {'_id': ObjectId('66a72d6248181a51a2035e43'), 'id': 63453, 'gender': 'Female', 'age': 56.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Govt_job', 'Residence_type': 'Rural', 'avg_glucose_level': 162.23, 'bmi': 27.3, 'smoking_status': 'Unknown', 'stroke': 1}
# Record Number, 138: {'_id': ObjectId('66a72d6248181a51a2035e45'), 'id': 44993, 'gender': 'Female', 'age': 79.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Govt_job', 'Residence_type': 'Urban', 'avg_glucose_level': 98.02, 'bmi': 22.3, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 139: {'_id': ObjectId('66a72d6248181a51a2035e51'), 'id': 54567, 'gender': 'Female', 'age': 46.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 78.18, 'bmi': 30.8, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 140: {'_id': ObjectId('66a72d6248181a51a2035e5f'), 'id': 23410, 'gender': 'Female', 'age': 72.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 97.92, 'bmi': 26.9, 'smoking_status': 'smokes', 'stroke': 1}
# Record Number, 141: {'_id': ObjectId('66a72d6248181a51a2035e72'), 'id': 66866, 'gender': 'Female', 'age': 48.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 74.11, 'bmi': 20.5, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 142: {'_id': ObjectId('66a72d6248181a51a2035e79'), 'id': 20463, 'gender': 'Male', 'age': 81.0, 'hypertension': 1, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 250.89, 'bmi': 28.1, 'smoking_status': 'smokes', 'stroke': 1}
# Record Number, 143: {'_id': ObjectId('66a72d6248181a51a2035e82'), 'id': 69959, 'gender': 'Female', 'age': 80.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 66.03, 'bmi': 35.4, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 144: {'_id': ObjectId('66a72d6248181a51a2035e99'), 'id': 56543, 'gender': 'Female', 'age': 70.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 69.04, 'bmi': 35.9, 'smoking_status': 'formerly smoked', 'stroke': 0}
# Record Number, 145: {'_id': ObjectId('66a72d6248181a51a2035ea6'), 'id': 19584, 'gender': 'Female', 'age': 20.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 84.62, 'bmi': 19.7, 'smoking_status': 'smokes', 'stroke': 0}
# Record Number, 146: {'_id': ObjectId('66a72d6248181a51a2035ebd'), 'id': 70970, 'gender': 'Female', 'age': 17.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 82.18, 'bmi': 23.4, 'smoking_status': 'Unknown', 'stroke': 0}
# Record Number, 147: {'_id': ObjectId('66a72d6248181a51a2035ec6'), 'id': 67318, 'gender': 'Male', 'age': 58.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Govt_job', 'Residence_type': 'Rural', 'avg_glucose_level': 56.96, 'bmi': 26.8, 'smoking_status': 'smokes', 'stroke': 0}
# Record Number, 148: {'_id': ObjectId('66a72d6248181a51a2035ee2'), 'id': 4480, 'gender': 'Male', 'age': 76.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 234.58, 'bmi': 34.3, 'smoking_status': 'formerly smoked', 'stroke': 0}
# Record Number, 149: {'_id': ObjectId('66a72d6248181a51a2035ee4'), 'id': 65535, 'gender': 'Male', 'age': 8.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 78.05, 'bmi': 25.7, 'smoking_status': 'Unknown', 'stroke': 0}
# Record Number, 150: {'_id': ObjectId('66a72d6248181a51a2035eee'), 'id': 56357, 'gender': 'Female', 'age': 82.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 215.6, 'bmi': 24.9, 'smoking_status': 'never smoked', 'stroke': 0}
# Record Number, 151: {'_id': ObjectId('66a72d6248181a51a2035f00'), 'id': 49421, 'gender': 'Female', 'age': 66.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 205.23, 'bmi': 39.5, 'smoking_status': 'never smoked', 'stroke': 0}
# Record Number, 152: {'_id': ObjectId('66a72d6248181a51a2035f2e'), 'id': 49465, 'gender': 'Female', 'age': 13.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 70.16, 'bmi': 21.2, 'smoking_status': 'never smoked', 'stroke': 0}
# Record Number, 153: {'_id': ObjectId('66a72d6248181a51a2035f45'), 'id': 20546, 'gender': 'Female', 'age': 68.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 79.58, 'bmi': 22.2, 'smoking_status': 'never smoked', 'stroke': 0}
# ...
# Record Number, 5059: {'_id': ObjectId('66a72d6248181a51a20370bf'), 'id': 54795, 'gender': 'Female', 'age': 12.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 132.85, 'bmi': 16.2, 'smoking_status': 'never smoked', 'stroke': 0}
# Record Number, 5060: {'_id': ObjectId('66a72d6248181a51a20370c1'), 'id': 34084, 'gender': 'Male', 'age': 7.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 77.12, 'bmi': 18.6, 'smoking_status': 'Unknown', 'stroke': 0}
# Record Number, 5061: {'_id': ObjectId('66a72d6248181a51a20370e2'), 'id': 8690, 'gender': 'Female', 'age': 81.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 80.44, 'bmi': 32.2, 'smoking_status': 'never smoked', 'stroke': 0}
# Record Number, 5062: {'_id': ObjectId('66a72d6248181a51a20370e3'), 'id': 32147, 'gender': 'Male', 'age': 1.32, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 107.02, 'bmi': nan, 'smoking_status': 'Unknown', 'stroke': 0}
# Record Number, 5063: {'_id': ObjectId('66a72d6248181a51a2037105'), 'id': 45160, 'gender': 'Male', 'age': 3.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 78.24, 'bmi': 16.2, 'smoking_status': 'Unknown', 'stroke': 0}
# Record Number, 5064: {'_id': ObjectId('66a72d6248181a51a2037108'), 'id': 39393, 'gender': 'Female', 'age': 63.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 57.06, 'bmi': 37.9, 'smoking_status': 'never smoked', 'stroke': 0}
# Record Number, 5065: {'_id': ObjectId('66a72d6248181a51a2037114'), 'id': 10995, 'gender': 'Male', 'age': 76.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 267.6, 'bmi': 30.5, 'smoking_status': 'never smoked', 'stroke': 0}
# Record Number, 5066: {'_id': ObjectId('66a72d6248181a51a2037128'), 'id': 63158, 'gender': 'Male', 'age': 17.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 63.28, 'bmi': 40.2, 'smoking_status': 'Unknown', 'stroke': 0}
# Record Number, 5067: {'_id': ObjectId('66a72d6248181a51a2037168'), 'id': 65814, 'gender': 'Male', 'age': 21.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 138.51, 'bmi': 24.3, 'smoking_status': 'never smoked', 'stroke': 0}
# Record Number, 5068: {'_id': ObjectId('66a72d6248181a51a2037186'), 'id': 64520, 'gender': 'Male', 'age': 68.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 91.68, 'bmi': 40.8, 'smoking_status': 'Unknown', 'stroke': 0}
# Record Number, 5069: {'_id': ObjectId('66a72d6248181a51a2036eed'), 'id': 63773, 'gender': 'Female', 'age': 13.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 146.1, 'bmi': 22.8, 'smoking_status': 'never smoked', 'stroke': 0}
# Record Number, 5070: {'_id': ObjectId('66a72d6248181a51a2036ef0'), 'id': 54117, 'gender': 'Male', 'age': 7.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 103.5, 'bmi': 19.0, 'smoking_status': 'Unknown', 'stroke': 0}
# Record Number, 5071: {'_id': ObjectId('66a72d6248181a51a2036f0b'), 'id': 45279, 'gender': 'Female', 'age': 10.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 83.03, 'bmi': 18.5, 'smoking_status': 'Unknown', 'stroke': 0}
# Record Number, 5072: {'_id': ObjectId('66a72d6248181a51a2036f0e'), 'id': 8623, 'gender': 'Female', 'age': 3.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 78.79, 'bmi': 22.6, 'smoking_status': 'Unknown', 'stroke': 0}
# Record Number, 5073: {'_id': ObjectId('66a72d6248181a51a2036f29'), 'id': 34045, 'gender': 'Female', 'age': 8.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 87.15, 'bmi': 16.1, 'smoking_status': 'Unknown', 'stroke': 0}
# Record Number, 5074: {'_id': ObjectId('66a72d6248181a51a2036f2e'), 'id': 37440, 'gender': 'Male', 'age': 52.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Govt_job', 'Residence_type': 'Urban', 'avg_glucose_level': 208.39, 'bmi': 36.0, 'smoking_status': 'formerly smoked', 'stroke': 0}
# Record Number, 5075: {'_id': ObjectId('66a72d6248181a51a2036f3f'), 'id': 46670, 'gender': 'Female', 'age': 75.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Rural', 'avg_glucose_level': 197.06, 'bmi': 26.1, 'smoking_status': 'never smoked', 'stroke': 0}
# Record Number, 5076: {'_id': ObjectId('66a72d6248181a51a2036f47'), 'id': 22282, 'gender': 'Male', 'age': 52.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Govt_job', 'Residence_type': 'Rural', 'avg_glucose_level': 116.62, 'bmi': nan, 'smoking_status': 'smokes', 'stroke': 0}
# Record Number, 5077: {'_id': ObjectId('66a72d6248181a51a2036f6d'), 'id': 6605, 'gender': 'Male', 'age': 52.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Govt_job', 'Residence_type': 'Urban', 'avg_glucose_level': 235.06, 'bmi': 39.9, 'smoking_status': 'formerly smoked', 'stroke': 0}
# Record Number, 5078: {'_id': ObjectId('66a72d6248181a51a2036f7f'), 'id': 64155, 'gender': 'Male', 'age': 60.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Govt_job', 'Residence_type': 'Rural', 'avg_glucose_level': 200.25, 'bmi': 33.1, 'smoking_status': 'never smoked', 'stroke': 0}
# Record Number, 5079: {'_id': ObjectId('66a72d6248181a51a2036f96'), 'id': 25927, 'gender': 'Male', 'age': 36.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 106.73, 'bmi': 25.1, 'smoking_status': 'never smoked', 'stroke': 0}
# Record Number, 5080: {'_id': ObjectId('66a72d6248181a51a2036fa4'), 'id': 69972, 'gender': 'Female', 'age': 55.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 56.11, 'bmi': 32.4, 'smoking_status': 'formerly smoked', 'stroke': 0}
# Record Number, 5081: {'_id': ObjectId('66a72d6248181a51a2036fc0'), 'id': 65038, 'gender': 'Female', 'age': 33.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 57.1, 'bmi': 33.1, 'smoking_status': 'never smoked', 'stroke': 0}
# Record Number, 5082: {'_id': ObjectId('66a72d6248181a51a2036fcb'), 'id': 27623, 'gender': 'Female', 'age': 59.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 200.8, 'bmi': 32.3, 'smoking_status': 'Unknown', 'stroke': 0}
# Record Number, 5083: {'_id': ObjectId('66a72d6248181a51a2036fe6'), 'id': 11843, 'gender': 'Female', 'age': 65.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Rural', 'avg_glucose_level': 80.42, 'bmi': 29.4, 'smoking_status': 'formerly smoked', 'stroke': 0}
# Record Number, 5084: {'_id': ObjectId('66a72d6248181a51a2036ff9'), 'id': 47216, 'gender': 'Male', 'age': 47.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 110.14, 'bmi': 30.5, 'smoking_status': 'smokes', 'stroke': 0}
# Record Number, 5085: {'_id': ObjectId('66a72d6248181a51a203700d'), 'id': 8111, 'gender': 'Female', 'age': 23.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 104.09, 'bmi': 27.9, 'smoking_status': 'Unknown', 'stroke': 0}
# Record Number, 5086: {'_id': ObjectId('66a72d6248181a51a2037013'), 'id': 46015, 'gender': 'Female', 'age': 29.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 73.63, 'bmi': 22.5, 'smoking_status': 'smokes', 'stroke': 0}
# Record Number, 5087: {'_id': ObjectId('66a72d6248181a51a203701c'), 'id': 35660, 'gender': 'Male', 'age': 18.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 115.46, 'bmi': 27.6, 'smoking_status': 'Unknown', 'stroke': 0}
# Record Number, 5088: {'_id': ObjectId('66a72d6248181a51a2037027'), 'id': 52882, 'gender': 'Female', 'age': 60.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Govt_job', 'Residence_type': 'Rural', 'avg_glucose_level': 111.79, 'bmi': 23.6, 'smoking_status': 'smokes', 'stroke': 0}
# Record Number, 5089: {'_id': ObjectId('66a72d6248181a51a203705e'), 'id': 57612, 'gender': 'Male', 'age': 62.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 81.64, 'bmi': 38.2, 'smoking_status': 'never smoked', 'stroke': 0}
# Record Number, 5090: {'_id': ObjectId('66a72d6248181a51a2037072'), 'id': 62471, 'gender': 'Female', 'age': 34.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Rural', 'avg_glucose_level': 68.53, 'bmi': 29.7, 'smoking_status': 'never smoked', 'stroke': 0}
# Record Number, 5091: {'_id': ObjectId('66a72d6248181a51a2037079'), 'id': 42091, 'gender': 'Male', 'age': 32.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Govt_job', 'Residence_type': 'Rural', 'avg_glucose_level': 83.01, 'bmi': 25.8, 'smoking_status': 'smokes', 'stroke': 0}
# Record Number, 5092: {'_id': ObjectId('66a72d6248181a51a203707d'), 'id': 72386, 'gender': 'Female', 'age': 20.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 61.88, 'bmi': 20.1, 'smoking_status': 'never smoked', 'stroke': 0}
# Record Number, 5093: {'_id': ObjectId('66a72d6248181a51a2037087'), 'id': 47383, 'gender': 'Male', 'age': 1.8, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 153.31, 'bmi': 17.1, 'smoking_status': 'Unknown', 'stroke': 0}
# Record Number, 5094: {'_id': ObjectId('66a72d6248181a51a2037092'), 'id': 62656, 'gender': 'Female', 'age': 14.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 101.6, 'bmi': 25.3, 'smoking_status': 'never smoked', 'stroke': 0}
# Record Number, 5095: {'_id': ObjectId('66a72d6248181a51a20370a9'), 'id': 45163, 'gender': 'Female', 'age': 47.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 99.36, 'bmi': 23.8, 'smoking_status': 'smokes', 'stroke': 0}
# Record Number, 5096: {'_id': ObjectId('66a72d6248181a51a20370b2'), 'id': 19165, 'gender': 'Male', 'age': 33.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 83.12, 'bmi': 23.4, 'smoking_status': 'Unknown', 'stroke': 0}
# Record Number, 5097: {'_id': ObjectId('66a72d6248181a51a20370c8'), 'id': 39708, 'gender': 'Male', 'age': 55.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 56.87, 'bmi': 28.9, 'smoking_status': 'formerly smoked', 'stroke': 0}
# Record Number, 5098: {'_id': ObjectId('66a72d6248181a51a20370d7'), 'id': 63650, 'gender': 'Female', 'age': 47.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Govt_job', 'Residence_type': 'Urban', 'avg_glucose_level': 135.79, 'bmi': 32.1, 'smoking_status': 'formerly smoked', 'stroke': 0}
# Record Number, 5099: {'_id': ObjectId('66a72d6248181a51a20370e1'), 'id': 5951, 'gender': 'Male', 'age': 28.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 86.61, 'bmi': 38.6, 'smoking_status': 'smokes', 'stroke': 0}
# Record Number, 5100: {'_id': ObjectId('66a72d6248181a51a20370fb'), 'id': 63986, 'gender': 'Male', 'age': 60.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 153.48, 'bmi': 37.3, 'smoking_status': 'never smoked', 'stroke': 0}
# Record Number, 5101: {'_id': ObjectId('66a72d6248181a51a2037133'), 'id': 30463, 'gender': 'Male', 'age': 29.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 82.93, 'bmi': 29.4, 'smoking_status': 'formerly smoked', 'stroke': 0}
# Record Number, 5102: {'_id': ObjectId('66a72d6248181a51a203713e'), 'id': 47461, 'gender': 'Female', 'age': 35.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 112.35, 'bmi': 29.9, 'smoking_status': 'Unknown', 'stroke': 0}
# Record Number, 5103: {'_id': ObjectId('66a72d6248181a51a2037142'), 'id': 66951, 'gender': 'Female', 'age': 72.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 206.49, 'bmi': 26.3, 'smoking_status': 'never smoked', 'stroke': 0}
# Record Number, 5104: {'_id': ObjectId('66a72d6248181a51a2037149'), 'id': 57159, 'gender': 'Male', 'age': 56.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Rural', 'avg_glucose_level': 125.87, 'bmi': 24.6, 'smoking_status': 'never smoked', 'stroke': 0}
# Record Number, 5105: {'_id': ObjectId('66a72d6248181a51a203714f'), 'id': 40220, 'gender': 'Male', 'age': 32.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 100.65, 'bmi': 26.2, 'smoking_status': 'formerly smoked', 'stroke': 0}
# Record Number, 5106: {'_id': ObjectId('66a72d6248181a51a203715c'), 'id': 11630, 'gender': 'Female', 'age': 25.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 92.06, 'bmi': 25.3, 'smoking_status': 'smokes', 'stroke': 0}
# Record Number, 5107: {'_id': ObjectId('66a72d6248181a51a2037179'), 'id': 29540, 'gender': 'Male', 'age': 67.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 97.04, 'bmi': 26.9, 'smoking_status': 'smokes', 'stroke': 0}
# Record Number, 5108: {'_id': ObjectId('66a72d6248181a51a203717c'), 'id': 26214, 'gender': 'Female', 'age': 63.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Rural', 'avg_glucose_level': 75.93, 'bmi': 34.7, 'smoking_status': 'formerly smoked', 'stroke': 0}
# Record Number, 5109: {'_id': ObjectId('66a72d6248181a51a2037184'), 'id': 68598, 'gender': 'Male', 'age': 1.08, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 79.15, 'bmi': 17.4, 'smoking_status': 'Unknown', 'stroke': 0}

# %%
client = pm.MongoClient(CONNECTION_URL,tlsCAFile=ca)
database = client[DB_NAME]
collection = database[COLLECTION_NAME]
# record = collection.insert_many(data)

# %%
records = collection.find()
records

# %%
for i, j in enumerate(records):
    print(f"Record Number, {i}: {j}")
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 for i, j in enumerate(records):
#       2     print(f"Record Number, {i}: {j}")
#
# File ~/miniconda3/envs/heart_disease/lib/python3.8/site-packages/pymongo/cursor.py:1176, in Cursor.next(self)
#    1174 if self.__empty:
#    1175     raise StopIteration
# -> 1176 if len(self.__data) or self._refresh():
#    1177     if self.__manipulate:
#    1178         _db = self.__collection.database
#
# File ~/miniconda3/envs/heart_disease/lib/python3.8/site-packages/pymongo/cursor.py:1087, in Cursor._refresh(self)
#    1072 if self.__id is None:  # Query
#    1073     q = self._query_class(self.__query_flags,
#    1074                           self.__collection.database.name,
#    1075                           self.__collection.name,
#    (...)
#    1085                           self.__session,
#    1086                           self.__collection.database.client)
# -> 1087     self.__send_message(q)
#    1088     if not self.__id:
#    1089         self.__killed = True
#
# File ~/miniconda3/envs/heart_disease/lib/python3.8/site-packages/pymongo/cursor.py:974, in Cursor.__send_message(self, operation)
#     972         first = docs[0]
#     973         client._receive_cluster_time(first, self.__session)
# --> 974         helpers._check_command_response(first)
#     975 except OperationFailure as exc:
#     976     self.__killed = True
#
# File ~/miniconda3/envs/heart_disease/lib/python3.8/site-packages/pymongo/helpers.py:146, in _check_command_response(response, msg, allowable_errors, parse_write_concern_error)
#     143     raise CursorNotFound(errmsg, code, response)
#     145 msg = msg or "%s"
# --> 146 raise OperationFailure(msg % errmsg, code, response)
#
# OperationFailure: Unsupported OP_QUERY command: find. The client driver may require an upgrade. For more details see https://dochub.mongodb.org/core/legacy-opcode-removal

# %%
df = pd.DataFrame(list(collection.find()))
df.head()
# print(df.columns)
# Out:
#                         _id     id  gender   age  hypertension  heart_disease  \
# 0  66a72d6248181a51a2035d9d   9046    Male  67.0             0              1
# 1  66a72d6248181a51a2035d9e  51676  Female  61.0             0              0
# 2  66a72d6248181a51a2035d9f  31112    Male  80.0             0              1
# 3  66a72d6248181a51a2035da0  60182  Female  49.0             0              0
# 4  66a72d6248181a51a2035da1   1665  Female  79.0             1              0
#
#   ever_married      work_type Residence_type  avg_glucose_level   bmi  \
# 0          Yes        Private          Urban             228.69  36.6
# 1          Yes  Self-employed          Rural             202.21   NaN
# 2          Yes        Private          Rural             105.92  32.5
# 3          Yes        Private          Urban             171.23  34.4
# 4          Yes  Self-employed          Rural             174.12  24.0
#
#     smoking_status  stroke
# 0  formerly smoked       1
# 1     never smoked       1
# 2     never smoked       1
# 3           smokes       1
# 4     never smoked       1
